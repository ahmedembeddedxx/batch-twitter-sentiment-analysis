# %%
# !pip install ntscraper

# %%
from ntscraper import Nitter

# %%
tweets = Nitter().get_tweets(terms = "geonews_english", mode="user", number = 20)
# Out:
# Testing instances: 100%|██████████| 77/77 [01:35<00:00,  1.25s/it]
# INFO:root:No instance specified, using random instance https://nitter.esmailelbob.xyz
# INFO:root:Current stats for geonews_english: 20 tweets, 0 threads...

# %%
df = pd.json_normalize(tweets['tweets'])

df = df[['text', 'date']]

df.sample(10)
# Out:
#                                                  text  \
# 6   Singing celebrities usually do not like fans j...
# 19  Muhammad Aurangzeb recalls notable reductions ...
# 17  Seven Customs officials had embraced martyrdom...
# 14  Iranian President Seyyed Ebrahim Raisi visits ...
# 18  Team management might reach any decision over ...
# 2   "8,000 out of 10,200 missing persons’ cases wi...
# 11  WARNING - DISTURBING CONTENT  Efforts underway...
# 5   Kanye West’s wife Bianca Censori was reportedl...
# 10  Prince Harry set to produce Netflix documentar...
# 13  Mobile phone services face disruption in some ...
#
#                            date
# 6    Apr 23, 2024 · 3:23 PM UTC
# 19   Apr 23, 2024 · 8:17 AM UTC
# 17   Apr 23, 2024 · 9:54 AM UTC
# 14  Apr 23, 2024 · 12:30 PM UTC
# 18   Apr 23, 2024 · 9:16 AM UTC
# 2    Apr 23, 2024 · 5:09 PM UTC
# 11   Apr 23, 2024 · 1:26 PM UTC
# 5    Apr 23, 2024 · 3:37 PM UTC
# 10   Apr 23, 2024 · 1:56 PM UTC
# 13  Apr 23, 2024 · 12:47 PM UTC

# %%
df.to_csv('data.csv', index = False)
